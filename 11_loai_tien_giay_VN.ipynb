# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator, image
from keras.layers import Dense,Activation,Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras.models import  Sequential

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd

# %%
train_data = '/content/drive/MyDrive/Baitap_AI/tien_VN/train'
test_data =  '/content/drive/MyDrive/Baitap_AI/tien_VN/test'
val_data  =  '/content/drive/MyDrive/Baitap_AI/tien_VN/test'

# %%
from keras.engine.data_adapter import train_validation_split

# %%
data_scale = ImageDataGenerator(rescale=1. / 255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
train_input = data_scale.flow_from_directory(train_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
test_input = data_scale.flow_from_directory(test_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
val_input = data_scale.flow_from_directory(val_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
# Out:
# Found 190 images belonging to 11 classes.
# Found 121 images belonging to 11 classes.
# Found 121 images belonging to 11 classes.

# %%
class_name = ['200', '500', '1000', '2000', '5000', '10000', '20000', '50000', '100000', '200000','500000']

# %%
print("labels: ", class_name)
print("match class: ", train_input.class_indices)
print("Tổng cộng số loại tiền giấy: ",train_input.num_classes)
# Out:
# labels:  ['200', '500', '1000', '2000', '5000', '10000', '20000', '50000', '100000', '200000', '500000']
# match class:  {'1000': 0, '10000': 1, '100000': 2, '200': 3, '2000': 4, '20000': 5, '200000': 6, '500': 7, '5000': 8, '50000': 9, '500000': 10}
# Tổng cộng số loại tiền giấy:  11

# %%
model=Sequential()

model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same', input_shape=(120,120,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

# %%
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(11,activation='softmax'))  
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 120, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 32)       0
#  )
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 3,797,707
# Trainable params: 3,797,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
money_train = model.fit(train_input,batch_size=30,epochs=100,verbose=1,validation_data=val_input)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 192s 32s/step - loss: 10.0667 - accuracy: 0.0684 - val_loss: 2.4062 - val_accuracy: 0.0992
# Epoch 2/100
# 6/6 [==============================] - 5s 984ms/step - loss: 2.6369 - accuracy: 0.1053 - val_loss: 2.3977 - val_accuracy: 0.0909
# Epoch 3/100
# 6/6 [==============================] - 5s 998ms/step - loss: 2.3817 - accuracy: 0.1158 - val_loss: 2.3960 - val_accuracy: 0.1157
# Epoch 4/100
# 6/6 [==============================] - 5s 973ms/step - loss: 2.3733 - accuracy: 0.1421 - val_loss: 2.3882 - val_accuracy: 0.1240
# Epoch 5/100
# 6/6 [==============================] - 5s 987ms/step - loss: 2.4032 - accuracy: 0.1158 - val_loss: 2.3854 - val_accuracy: 0.1322
# Epoch 6/100
# 6/6 [==============================] - 5s 960ms/step - loss: 2.3525 - accuracy: 0.1000 - val_loss: 2.3744 - val_accuracy: 0.1240
# Epoch 7/100
# 6/6 [==============================] - 5s 969ms/step - loss: 2.3461 - accuracy: 0.1474 - val_loss: 2.3647 - val_accuracy: 0.1322
# Epoch 8/100
# 6/6 [==============================] - 5s 974ms/step - loss: 2.3427 - accuracy: 0.1421 - val_loss: 2.3706 - val_accuracy: 0.1488
# Epoch 9/100
# 6/6 [==============================] - 5s 974ms/step - loss: 2.3510 - accuracy: 0.1474 - val_loss: 2.3475 - val_accuracy: 0.1322
# Epoch 10/100
# 6/6 [==============================] - 5s 928ms/step - loss: 2.3031 - accuracy: 0.1474 - val_loss: 2.3158 - val_accuracy: 0.1736
# Epoch 11/100
# 6/6 [==============================] - 5s 946ms/step - loss: 2.2853 - accuracy: 0.2053 - val_loss: 2.3046 - val_accuracy: 0.1405
# Epoch 12/100
# 6/6 [==============================] - 5s 889ms/step - loss: 2.2458 - accuracy: 0.1737 - val_loss: 2.3158 - val_accuracy: 0.1570
# Epoch 13/100
# 6/6 [==============================] - 5s 920ms/step - loss: 2.2398 - accuracy: 0.2053 - val_loss: 2.2393 - val_accuracy: 0.2314
# Epoch 14/100
# 6/6 [==============================] - 5s 960ms/step - loss: 2.1510 - accuracy: 0.2316 - val_loss: 2.2119 - val_accuracy: 0.2397
# Epoch 15/100
# 6/6 [==============================] - 5s 987ms/step - loss: 2.1691 - accuracy: 0.2000 - val_loss: 2.2203 - val_accuracy: 0.1983
# Epoch 16/100
# 6/6 [==============================] - 5s 963ms/step - loss: 2.0587 - accuracy: 0.3000 - val_loss: 2.1614 - val_accuracy: 0.2397
# Epoch 17/100
# 6/6 [==============================] - 5s 945ms/step - loss: 2.0355 - accuracy: 0.3000 - val_loss: 2.1269 - val_accuracy: 0.2645
# Epoch 18/100
# 6/6 [==============================] - 5s 973ms/step - loss: 2.0276 - accuracy: 0.2737 - val_loss: 2.1334 - val_accuracy: 0.2893
# Epoch 19/100
# 6/6 [==============================] - 5s 941ms/step - loss: 1.9965 - accuracy: 0.2895 - val_loss: 2.1063 - val_accuracy: 0.2975
# Epoch 20/100
# 6/6 [==============================] - 5s 965ms/step - loss: 1.8878 - accuracy: 0.3474 - val_loss: 2.0814 - val_accuracy: 0.2975
# Epoch 21/100
# 6/6 [==============================] - 5s 970ms/step - loss: 1.8076 - accuracy: 0.3684 - val_loss: 2.0194 - val_accuracy: 0.3223
# Epoch 22/100
# 6/6 [==============================] - 5s 964ms/step - loss: 1.8325 - accuracy: 0.3684 - val_loss: 1.9975 - val_accuracy: 0.2975
# Epoch 23/100
# 6/6 [==============================] - 5s 947ms/step - loss: 1.8626 - accuracy: 0.3368 - val_loss: 2.0082 - val_accuracy: 0.2975
# Epoch 24/100
# 6/6 [==============================] - 5s 957ms/step - loss: 1.8170 - accuracy: 0.3737 - val_loss: 2.0047 - val_accuracy: 0.3554
# Epoch 25/100
# 6/6 [==============================] - 5s 939ms/step - loss: 1.7819 - accuracy: 0.4421 - val_loss: 2.0038 - val_accuracy: 0.3306
# Epoch 26/100
# 6/6 [==============================] - 5s 983ms/step - loss: 1.7217 - accuracy: 0.3789 - val_loss: 2.1008 - val_accuracy: 0.2975
# Epoch 27/100
# 6/6 [==============================] - 5s 979ms/step - loss: 1.7504 - accuracy: 0.3737 - val_loss: 1.9537 - val_accuracy: 0.3719
# Epoch 28/100
# 6/6 [==============================] - 5s 969ms/step - loss: 1.7593 - accuracy: 0.3842 - val_loss: 1.9316 - val_accuracy: 0.3636
# Epoch 29/100
# 6/6 [==============================] - 5s 946ms/step - loss: 1.7654 - accuracy: 0.4105 - val_loss: 1.9330 - val_accuracy: 0.3802
# Epoch 30/100
# 6/6 [==============================] - 5s 980ms/step - loss: 1.6071 - accuracy: 0.4737 - val_loss: 1.9478 - val_accuracy: 0.3223
# Epoch 31/100
# 6/6 [==============================] - 5s 989ms/step - loss: 1.6716 - accuracy: 0.3842 - val_loss: 1.8808 - val_accuracy: 0.3884
# Epoch 32/100
# 6/6 [==============================] - 5s 954ms/step - loss: 1.5341 - accuracy: 0.4789 - val_loss: 1.8266 - val_accuracy: 0.4298
# Epoch 33/100
# 6/6 [==============================] - 5s 935ms/step - loss: 1.5549 - accuracy: 0.4316 - val_loss: 1.8514 - val_accuracy: 0.3967
# Epoch 34/100
# 6/6 [==============================] - 5s 977ms/step - loss: 1.4112 - accuracy: 0.5474 - val_loss: 1.7739 - val_accuracy: 0.4793
# Epoch 35/100
# 6/6 [==============================] - 5s 971ms/step - loss: 1.5097 - accuracy: 0.5263 - val_loss: 1.8554 - val_accuracy: 0.3719
# Epoch 36/100
# 6/6 [==============================] - 5s 975ms/step - loss: 1.5309 - accuracy: 0.5000 - val_loss: 1.8234 - val_accuracy: 0.4132
# Epoch 37/100
# 6/6 [==============================] - 5s 973ms/step - loss: 1.5614 - accuracy: 0.4632 - val_loss: 1.8268 - val_accuracy: 0.3967
# Epoch 38/100
# 6/6 [==============================] - 5s 975ms/step - loss: 1.4630 - accuracy: 0.5105 - val_loss: 1.7962 - val_accuracy: 0.4380
# Epoch 39/100
# 6/6 [==============================] - 5s 959ms/step - loss: 1.4484 - accuracy: 0.4895 - val_loss: 1.8552 - val_accuracy: 0.4298
# Epoch 40/100
# 6/6 [==============================] - 5s 933ms/step - loss: 1.3527 - accuracy: 0.5632 - val_loss: 1.7948 - val_accuracy: 0.4380
# Epoch 41/100
# 6/6 [==============================] - 5s 1s/step - loss: 1.2929 - accuracy: 0.6000 - val_loss: 1.7476 - val_accuracy: 0.4545
# Epoch 42/100
# 6/6 [==============================] - 5s 967ms/step - loss: 1.2727 - accuracy: 0.6053 - val_loss: 1.7855 - val_accuracy: 0.4463
# Epoch 43/100
# 6/6 [==============================] - 5s 949ms/step - loss: 1.3754 - accuracy: 0.5105 - val_loss: 1.8696 - val_accuracy: 0.4380
# Epoch 44/100
# 6/6 [==============================] - 5s 967ms/step - loss: 1.2466 - accuracy: 0.5789 - val_loss: 1.6599 - val_accuracy: 0.4380
# Epoch 45/100
# 6/6 [==============================] - 5s 953ms/step - loss: 1.3067 - accuracy: 0.5737 - val_loss: 1.7460 - val_accuracy: 0.4876
# Epoch 46/100
# 6/6 [==============================] - 5s 971ms/step - loss: 1.2097 - accuracy: 0.5737 - val_loss: 1.6439 - val_accuracy: 0.4876
# Epoch 47/100
# 6/6 [==============================] - 5s 968ms/step - loss: 1.2296 - accuracy: 0.5842 - val_loss: 1.6592 - val_accuracy: 0.4959
# Epoch 48/100
# 6/6 [==============================] - 5s 949ms/step - loss: 1.2618 - accuracy: 0.6000 - val_loss: 1.6402 - val_accuracy: 0.4628
# Epoch 49/100
# 6/6 [==============================] - 5s 946ms/step - loss: 1.1420 - accuracy: 0.5947 - val_loss: 1.6675 - val_accuracy: 0.5041
# Epoch 50/100
# 6/6 [==============================] - 5s 975ms/step - loss: 1.1309 - accuracy: 0.6474 - val_loss: 1.6518 - val_accuracy: 0.4793
# Epoch 51/100
# 6/6 [==============================] - 5s 953ms/step - loss: 1.1375 - accuracy: 0.6053 - val_loss: 1.5520 - val_accuracy: 0.5289
# Epoch 52/100
# 6/6 [==============================] - 5s 940ms/step - loss: 1.0601 - accuracy: 0.6000 - val_loss: 1.6553 - val_accuracy: 0.5041
# Epoch 53/100
# 6/6 [==============================] - 5s 968ms/step - loss: 1.0552 - accuracy: 0.6368 - val_loss: 1.6143 - val_accuracy: 0.5537
# Epoch 54/100
# 6/6 [==============================] - 5s 994ms/step - loss: 0.9588 - accuracy: 0.7053 - val_loss: 1.6398 - val_accuracy: 0.5041
# Epoch 55/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.9496 - accuracy: 0.6684 - val_loss: 1.5999 - val_accuracy: 0.5372
# Epoch 56/100
# 6/6 [==============================] - 5s 987ms/step - loss: 1.0174 - accuracy: 0.6632 - val_loss: 1.7073 - val_accuracy: 0.5207
# Epoch 57/100
# 6/6 [==============================] - 5s 971ms/step - loss: 0.9070 - accuracy: 0.7105 - val_loss: 1.5674 - val_accuracy: 0.5455
# Epoch 58/100
# 6/6 [==============================] - 5s 993ms/step - loss: 0.8798 - accuracy: 0.7000 - val_loss: 1.5799 - val_accuracy: 0.5289
# Epoch 59/100
# 6/6 [==============================] - 5s 996ms/step - loss: 0.9080 - accuracy: 0.6789 - val_loss: 1.6810 - val_accuracy: 0.5372
# Epoch 60/100
# 6/6 [==============================] - 5s 978ms/step - loss: 0.9217 - accuracy: 0.7000 - val_loss: 1.6755 - val_accuracy: 0.5372
# Epoch 61/100
# 6/6 [==============================] - 5s 960ms/step - loss: 0.9278 - accuracy: 0.7105 - val_loss: 1.4178 - val_accuracy: 0.5289
# Epoch 62/100
# 6/6 [==============================] - 5s 947ms/step - loss: 0.8141 - accuracy: 0.7263 - val_loss: 1.3459 - val_accuracy: 0.6281
# Epoch 63/100
# 6/6 [==============================] - 5s 939ms/step - loss: 0.8535 - accuracy: 0.7368 - val_loss: 1.6239 - val_accuracy: 0.5289
# Epoch 64/100
# 6/6 [==============================] - 5s 917ms/step - loss: 0.8740 - accuracy: 0.7421 - val_loss: 1.4605 - val_accuracy: 0.5620
# Epoch 65/100
# 6/6 [==============================] - 5s 955ms/step - loss: 0.8013 - accuracy: 0.7158 - val_loss: 1.4164 - val_accuracy: 0.6033
# Epoch 66/100
# 6/6 [==============================] - 5s 977ms/step - loss: 0.7708 - accuracy: 0.7263 - val_loss: 1.4074 - val_accuracy: 0.5785
# Epoch 67/100
# 6/6 [==============================] - 5s 989ms/step - loss: 0.9172 - accuracy: 0.6842 - val_loss: 1.3670 - val_accuracy: 0.6033
# Epoch 68/100
# 6/6 [==============================] - 5s 956ms/step - loss: 0.8219 - accuracy: 0.7316 - val_loss: 1.3001 - val_accuracy: 0.5950
# Epoch 69/100
# 6/6 [==============================] - 5s 985ms/step - loss: 0.7106 - accuracy: 0.7526 - val_loss: 1.4136 - val_accuracy: 0.5702
# Epoch 70/100
# 6/6 [==============================] - 5s 968ms/step - loss: 0.8160 - accuracy: 0.7368 - val_loss: 1.2523 - val_accuracy: 0.5868
# Epoch 71/100
# 6/6 [==============================] - 5s 939ms/step - loss: 0.6650 - accuracy: 0.7474 - val_loss: 1.4420 - val_accuracy: 0.5537
# Epoch 72/100
# 6/6 [==============================] - 5s 952ms/step - loss: 0.6290 - accuracy: 0.7842 - val_loss: 1.4684 - val_accuracy: 0.5372
# Epoch 73/100
# 6/6 [==============================] - 5s 995ms/step - loss: 0.6181 - accuracy: 0.7684 - val_loss: 1.4366 - val_accuracy: 0.5620
# Epoch 74/100
# 6/6 [==============================] - 5s 948ms/step - loss: 0.6746 - accuracy: 0.7316 - val_loss: 1.4653 - val_accuracy: 0.5702
# Epoch 75/100
# 6/6 [==============================] - 5s 961ms/step - loss: 0.5947 - accuracy: 0.8158 - val_loss: 1.4246 - val_accuracy: 0.6116
# Epoch 76/100
# 6/6 [==============================] - 5s 990ms/step - loss: 0.5099 - accuracy: 0.8368 - val_loss: 1.3646 - val_accuracy: 0.5785
# Epoch 77/100
# 6/6 [==============================] - 5s 951ms/step - loss: 0.6227 - accuracy: 0.8211 - val_loss: 1.6920 - val_accuracy: 0.5785
# Epoch 78/100
# 6/6 [==============================] - 5s 935ms/step - loss: 0.8030 - accuracy: 0.7316 - val_loss: 1.5487 - val_accuracy: 0.5950
# Epoch 79/100
# 6/6 [==============================] - 5s 946ms/step - loss: 0.6529 - accuracy: 0.7684 - val_loss: 1.6280 - val_accuracy: 0.5702
# Epoch 80/100
# 6/6 [==============================] - 5s 1s/step - loss: 0.6811 - accuracy: 0.7684 - val_loss: 1.5330 - val_accuracy: 0.5455
# Epoch 81/100
# 6/6 [==============================] - 5s 954ms/step - loss: 0.6365 - accuracy: 0.8053 - val_loss: 1.4910 - val_accuracy: 0.5868
# Epoch 82/100
# 6/6 [==============================] - 5s 972ms/step - loss: 0.4676 - accuracy: 0.8316 - val_loss: 1.5784 - val_accuracy: 0.5785
# Epoch 83/100
# 6/6 [==============================] - 5s 984ms/step - loss: 0.6285 - accuracy: 0.7895 - val_loss: 1.4523 - val_accuracy: 0.5620
# Epoch 84/100
# 6/6 [==============================] - 5s 975ms/step - loss: 0.5252 - accuracy: 0.8263 - val_loss: 1.5427 - val_accuracy: 0.6198
# Epoch 85/100
# 6/6 [==============================] - 5s 925ms/step - loss: 0.5842 - accuracy: 0.8105 - val_loss: 1.4602 - val_accuracy: 0.6198
# Epoch 86/100
# 6/6 [==============================] - 5s 934ms/step - loss: 0.4742 - accuracy: 0.8421 - val_loss: 1.6443 - val_accuracy: 0.5785
# Epoch 87/100
# 6/6 [==============================] - 5s 977ms/step - loss: 0.5007 - accuracy: 0.8368 - val_loss: 1.4040 - val_accuracy: 0.5868
# Epoch 88/100
# 6/6 [==============================] - 5s 956ms/step - loss: 0.5064 - accuracy: 0.8421 - val_loss: 1.4193 - val_accuracy: 0.5702
# Epoch 89/100
# 6/6 [==============================] - 5s 935ms/step - loss: 0.3811 - accuracy: 0.8737 - val_loss: 1.4326 - val_accuracy: 0.6281
# Epoch 90/100
# 6/6 [==============================] - 5s 937ms/step - loss: 0.4597 - accuracy: 0.8368 - val_loss: 1.4523 - val_accuracy: 0.6033
# Epoch 91/100
# 6/6 [==============================] - 5s 957ms/step - loss: 0.4390 - accuracy: 0.8632 - val_loss: 1.3848 - val_accuracy: 0.6198
# Epoch 92/100
# 6/6 [==============================] - 5s 946ms/step - loss: 0.4200 - accuracy: 0.8421 - val_loss: 1.4825 - val_accuracy: 0.6198
# Epoch 93/100
# 6/6 [==============================] - 5s 964ms/step - loss: 0.4536 - accuracy: 0.8579 - val_loss: 1.4850 - val_accuracy: 0.6198
# Epoch 94/100
# 6/6 [==============================] - 5s 948ms/step - loss: 0.3879 - accuracy: 0.8789 - val_loss: 1.7158 - val_accuracy: 0.6116
# Epoch 95/100
# 6/6 [==============================] - 5s 951ms/step - loss: 0.4950 - accuracy: 0.8000 - val_loss: 1.4786 - val_accuracy: 0.6033
# Epoch 96/100
# 6/6 [==============================] - 5s 978ms/step - loss: 0.4328 - accuracy: 0.8368 - val_loss: 1.5907 - val_accuracy: 0.5785
# Epoch 97/100
# 6/6 [==============================] - 5s 964ms/step - loss: 0.3990 - accuracy: 0.8684 - val_loss: 1.2502 - val_accuracy: 0.6198
# Epoch 98/100
# 6/6 [==============================] - 5s 979ms/step - loss: 0.4066 - accuracy: 0.8737 - val_loss: 1.3157 - val_accuracy: 0.6116
# Epoch 99/100
# 6/6 [==============================] - 5s 954ms/step - loss: 0.4914 - accuracy: 0.8158 - val_loss: 1.4811 - val_accuracy: 0.6446
# Epoch 100/100
# 6/6 [==============================] - 5s 965ms/step - loss: 0.4144 - accuracy: 0.8789 - val_loss: 1.5497 - val_accuracy: 0.6116

# %%
model.save('/content/drive/MyDrive/Baitap_AI/tien_VN/money.h5')

# %%
pic = image.load_img('/content/drive/MyDrive/Baitap_AI/tien_VN/10000.jpg', target_size=(120,120)) 
plt.imshow(pic)
pic = img_to_array(pic)
pic = pic.reshape(1,120,120,3) 
pic = pic.astype('float32')
pic = pic/255
np.argmax(model.predict(pic), axis=1)
# Out:
# array([1])

# %%
guess=np.argmax(model.predict(pic), axis=1)

# %%
if guess[0]==0:
  print("Loai tien: 1000")
if guess[0]==1:
  print("Loai tien: 10000")
if guess[0]==2:
  print("Loai tien: 100000")
if guess[0]==3:
  print("Loai tien: 200")
if guess[0]==4:
  print("Loai tien: 2000")
if guess[0]==5:
  print("Loai tien: 20000")
if guess[0]==6:
  print("Loai tien: 200000")
if guess[0]==7:
  print("Loai tien: 500")
if guess[0]==8:
  print("Loai tien: 5000")
if guess[0]==9:
  print("Loai tien: 50000")
if guess[0]==10:
  print("Loai tien: 500000")
# Out:
# Loai tien: 10000
